# %%
import pandas as pd

# %%
df = pd.read_parquet("gs://jmcybulde/data/processed/default_run/train.parquet")

# %%
df[df["cleaned_text"].str.split().apply(len) < 2]
# Out:
# Empty DataFrame
# Columns: [text, dataset_name, split, label, cleaned_text]
# Index: []

# %%
df.sample(10)
# Out:
#                                                      text dataset_name  split  \
# 21750   Somebody forgot the Nürnberg trials. Military ...          ghc  train
# 121930  It is not your place to delete comments by oth...          jtc  train
# 10867   *176.249.64.56 Edit warrior, after being warne...          jtc  train
# 130393  it may be a no-go then, but I'll do some inves...          jtc  train
# 21744   " Another Well Wisher ==
#
#  Another anonymous ...          jtc  train
# 132401  Spot, grow up!  The article is being improved ...          jtc  train
# 47353   "
#
#  :It is a kind of tough idea to get across...          jtc  train
# 135046  "
#
#  GFY, GorillaPitBull
#
# Based on your Wiki p...          jtc  train
# 10660   When you don't really know why you believe wha...          ghc  train
# 18112   Anti white Jew?  Where in the world did you co...          ghc  train
#
#         label                                       cleaned_text
# 21750       0  somebody forgot trials military tribunals nt s...
# 121930      0         it place delete comments editors talk page
# 10867       0                          edit warrior warned email
# 130393      0  may nogo i ll investigation let know allkpop r...
# 21744       0  another well wisher another anonymous well wis...
# 132401      1  spot grow the article improved new structure p...
# 47353       0  it kind tough idea get across i try explain be...
# 135046      0  gfy gorillapitbull based wiki photo incorporat...
# 10660       0  when nt really know believe ve convinced belie...
# 18112       0  anti white jew where world come utter nonsense...

# %%
another_df[another_df["cleaned_text"].str.split().apply(len) < 2]
# Out:
# Empty DataFrame
# Columns: [text, split, label, dataset_name, cleaned_text]
# Index: []
