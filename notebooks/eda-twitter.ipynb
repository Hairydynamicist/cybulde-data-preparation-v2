# %%
cd ../data/raw/twitter
# Out:
# /app/data/raw/twitter
# /home/johnm/venv/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
import pandas as pd

# %%
df = pd.read_csv("cyberbullying_tweets.csv")

# %%
df.sample(n=50)
# Out:
#                                               tweet_text   cyberbullying_type
# 25880  @Ruderzz generally, anytime you say "devil's a...  other_cyberbullying
# 23716  @SpeakerPelosi Nancy, since you think and spea...             religion
# 4910   rencananya , nnti mau makan bareng2 , gue,zaki...    not_cyberbullying
# 13365  Those bitchin, big-noting #MKR babes need to f...               gender
# 28066  We just launched missiles at Syria?!?! Are we ...  other_cyberbullying
# 27717           @Shervyn like i would owe you, big time.  other_cyberbullying
# 44332  RT @tayyoung_: FUCK OBAMA, dumb ass nigger &lt...            ethnicity
# 39336  Gay niggas always got hands .. especially if t...                  age
# 15977  Prophet Muhammad(saw) jihad was to serve human...             religion
# 33333  We cant just let this stand. Its even worse - ...                  age
# 10787  Yes, because *I* was the rude one. @TommyWard1...               gender
# ...

# %%
df.shape
# Out:
# (47692, 2)

# %%
print(set(df["cyberbullying_type"].unique()))
# Out:
# {'age', 'gender', 'not_cyberbullying', 'ethnicity', 'other_cyberbullying', 'religion'}
