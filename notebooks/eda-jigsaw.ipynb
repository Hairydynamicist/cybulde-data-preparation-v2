# %%
cd ../data/raw/jigsaw-toxic-comments
# Out:
# /app/data/raw/jigsaw-toxic-comments
# /home/johnm/venv/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
import pandas as pd

# %%
train_df = pd.read_csv("train.csv")
test_df = pd.read_csv("test.csv")
test_labels_df = pd.read_csv("test_labels.csv")

# %%
print(f"{train_df.shape}")
print(f"{test_df.shape}")
print(f"{test_labels_df.shape}")
# Out:
# (159571, 8)
# (153164, 2)
# (153164, 7)

# %%
train_df.sample(n=50)
# Out:
#                       id                                       comment_text  \
# 66488   b1e0d5ff51bb0253  Why is this article semi-protected? \n\nI don'...
# 101094  1d10549b29f7373c          Please??? I promise no more bad vandalism
# 143066  fd09be0e19670793  User:Larrypooplinson \n\nHello. I noticed your...
# 15551   290ed76ca42e4020  Not a forum. \n\nDon't worry, I'm done talking...
# 59122   9e5b6e5aaae82f83  "\n\n Re the surname Rossi Lemeni. \n\n       ...
# 36454   615ddd0785f544ff  "\n That's because there are none. When the st...
# 107642  3f6df56cadb7b349             facfailed|El Greco 1 (withdrawn)}}\n{{
# 42744   72111d8d6d9684ec  IMHO, intergovernmentalism and supranationalis...
# 43419   73e4256ad2eb373a  The image has a known source and it's verifiab...
# 113490  5eeaa110c7648e37  WP:NPA\nHello, .  This message is being sent t...
# 133199  c8ac1676caea78ae  I am certain that it is wrong to say categoric...
# 118124  77059e86c9aaddb5                       I never fire the first shot.
# 93514   fa0772484743f662  Derek's gone \n\nIt appears that your article ...
# 26906   4742f7d8bda02935  Happy Birthday, Michael! (Mar 10) \n\nPlease g...
# 30979   524b107b4c0490fa  Dude that was what the default personal attack...
# 29653   4ea75a9841cc2c89  "\n\nSecond warning on Harry S. Truman: Please...
# 139750  ebe38fb752e33228  Image:Calvin & Hobbes - Calvin.png \n\nHi Bubb...
# 103672  2aaeaf2b69c94b56  "\n\n A barnstar for you! \n\n  The Special Ba...
# 59521   9f6f16ac2b7e314e  So you are another vile little Englishman like...
# 158539  ef8da281c9c0cfa8  "\n\nNits and Appreciation from Robert Steele\...
# 110656  4ff13156f6cd179e  "\n\n timeline conflict \n\nThe Lovecraft quot...
# 80078   d645b5491cc71859  Zoe had to go, and that is not a personal atta...
# 6027    10162b41ef99c6cd  Is that General 9 ............\n\nIs that Gene...
# 72771   c2afac55b5e844c0  What on earth is the problem with you\nI clear...
# 137444  df734ea888351868  "\n\nMagog - My understanding was that 3RR is ...
# 80418   d727b747a62d23fc  Actually You seems to be over smart.No one is ...
# 141944  f75698db7505e290          REDIRECT Talk:2007–08 S.L. Benfica season
# 18684   31505457fe0b5668  WHERE CYDE DOES WHATEVER HE WEANTS AND NO ONE ...
# 70230   bbe45f1faa608911  "\nAgreed. Considering your response, I unders...
# 112498  59d009cc4de008cf  Your account isn't blocked from what I can tel...
# 6222    109e175f9a2627fb  March 2007 \n Please stop. If you continue to ...
# 121616  8aa6abd90c2e0f98  "\n\n Nude beach & controversy \n\nIn using th...
# 24464   40abb96aa7cce3a2  Will try - maybe if you put things here first,...
# 61129   a3a7b2979a0aad9a      Someone fill in the bracket!!!! 67.163.17.113
# 59205   9e9ae1f59fbd4304          P.S. What are you calling nonsense???????
# 57993   9b48b9deb24740f7  Welcome to Wikipedia! We welcome your help to ...
# 70341   bc32b2c6ae4d2afd  ", 4 October 2015 (UTC)\nOppose There is no ev...
# 32476   565f042293bd5f38  "\n\nPlease stop. If you continue to vandalize...
# 49479   844b24ec59c1d1bb  Thank you for experimenting with Wikipedia. Yo...
# 65930   b04d20b9087c117c  I could not find any mention of The Saga of Ha...
# 152993  95b57110c51c61bc  I've just deleted it again.  If you recreate i...
# 26612   468533f174c2a3b9  Thanks for your suggestion, but the editor who...
# 138062  e2d11fb3485a866a  Bollocks. That was an administrative action. T...
# 88705   ed4d252a47d8acba  ":::::Ahh I see...this kind of talk is ok, but...
# 81392   d9b556a50e5accab  And if you are unable to sign your posts, it p...
# 97432   09499cec4c6d793b  "\nThere are some sketchy things going on with...
# 62098   a621498108d288a3  Whether or not a statement is self-serving is ...
# 23404   3dcdd085a7acc5fc  Wikipedia:Requests for arbitration/Monicasdude...
# 43556   7443d142a32014d3  Inflation is always and everywhere a monetary ...
# 143022  fcce8e5bd8581c2b                               of divine revelation
#
#         toxic  severe_toxic  obscene  threat  insult  identity_hate
# 66488       0             0        0       0       0              0
# 101094      0             0        0       0       0              0
# 143066      0             0        0       0       0              0
# 15551       0             0        0       0       0              0
# 59122       0             0        0       0       0              0
# 36454       0             0        0       0       0              0
# 107642      0             0        0       0       0              0
# 42744       0             0        0       0       0              0
# 43419       0             0        0       0       0              0
# 113490      0             0        0       0       0              0
# 133199      0             0        0       0       0              0
# 118124      0             0        0       0       0              0
# 93514       0             0        0       0       0              0
# 26906       0             0        0       0       0              0
# 30979       0             0        0       0       0              0
# 29653       0             0        0       0       0              0
# 139750      0             0        0       0       0              0
# 103672      0             0        0       0       0              0
# 59521       1             0        1       0       1              1
# 158539      0             0        0       0       0              0
# 110656      0             0        0       0       0              0
# 80078       0             0        0       0       0              0
# 6027        0             0        0       0       0              0
# 72771       0             0        0       0       0              0
# 137444      0             0        0       0       0              0
# 80418       0             0        0       0       0              0
# 141944      0             0        0       0       0              0
# 18684       1             0        1       0       1              0
# 70230       0             0        0       0       0              0
# 112498      0             0        0       0       0              0
# 6222        0             0        0       0       0              0
# 121616      0             0        0       0       0              0
# 24464       0             0        0       0       0              0
# 61129       0             0        0       0       0              0
# 59205       0             0        0       0       0              0
# 57993       0             0        0       0       0              0
# 70341       0             0        0       0       0              0
# 32476       0             0        0       0       0              0
# 49479       0             0        0       0       0              0
# 65930       0             0        0       0       0              0
# 152993      0             0        0       0       0              0
# 26612       0             0        0       0       0              0
# 138062      0             0        0       0       0              0
# 88705       0             0        0       0       0              0
# 81392       0             0        0       0       0              0
# 97432       0             0        0       0       0              0
# 62098       0             0        0       0       0              0
# 23404       0             0        0       0       0              0
# 43556       0             0        0       0       0              0
# 143022      0             0        0       0       0              0

# %%
test_labels_df["toxic"].unique()
# Out:
# array([-1,  0,  1])

# %%
test_labels_df[test_labels_df["toxic"] != -1].shape
# Out:
# (63978, 7)

# %%
test_labels_df[
test_labels_df["toxic"] != -1].shape
# Out:
# (63978, 7)

# %%
test_labels_df.head()
# Out:
#                  id  toxic  severe_toxic  obscene  threat  insult  \
# 0  00001cee341fdb12     -1            -1       -1      -1      -1
# 1  0000247867823ef7     -1            -1       -1      -1      -1
# 2  00013b17ad220c46     -1            -1       -1      -1      -1
# 3  00017563c3f7919a     -1            -1       -1      -1      -1
# 4  00017695ad8997eb     -1            -1       -1      -1      -1
#
#    identity_hate
# 0             -1
# 1             -1
# 2             -1
# 3             -1
# 4             -1
